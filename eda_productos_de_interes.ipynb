# %% [markdown]
# # Análisis exploratorio de datos de productos de interés

# %% [markdown]
# ## Importar módulos

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()

# %% [markdown]
# ## Cargar datos

# %%
data = pd.read_csv("data\\datos_puebla.csv")
print(data.shape)
data.head()
# Out:
# (981610, 15)
#             producto                    presentacion             marca  \
# 0  ASISTENTES DE VOZ           NEST MINI O GA00781LA            GOOGLE
# 1        ASPIRADORAS      KC1500 POTENCIA 1400 WATTS     KOBLENZ ALPHA
# 2         AUTOPISTAS  FNB21 BATALLA EN PLAYA TIBURON  HOT WHEELSMATTEL
# 3         AUTOPISTAS      GJM77 DESAFIO DE LA RULETA  HOT WHEELSMATTEL
# 4         AUTOPISTAS            GNL70 GARAGE EXTREMO  HOT WHEELSMATTEL
#
#                         categoria           catalogo  precio  fechaRegistro  \
# 0           APARATOS ELECTRONICOS  ELECTRODOMESTICOS  1299.0       20230102
# 1             APARATOS ELECTRICOS  ELECTRODOMESTICOS  4499.0       20230102
# 2  ARTS DE ESPARCIMIENTO JUGUETES           JUGUETES  1035.0       20230102
# 3  ARTS DE ESPARCIMIENTO JUGUETES           JUGUETES   925.0       20230102
# 4  ARTS DE ESPARCIMIENTO JUGUETES           JUGUETES   815.0       20230102
#
#      cadenaComercial                    giro  \
# 0  PALACIO DE HIERRO  TIENDA DEPARTAMENTALES
# 1  PALACIO DE HIERRO  TIENDA DEPARTAMENTALES
# 2  PALACIO DE HIERRO  TIENDA DEPARTAMENTALES
# 3  PALACIO DE HIERRO  TIENDA DEPARTAMENTALES
# 4  PALACIO DE HIERRO  TIENDA DEPARTAMENTALES
#
#                         nombreComercial  \
# 0  EL PALACIO DE HIERRO SUCURSAL PUEBLA
# 1  EL PALACIO DE HIERRO SUCURSAL PUEBLA
# 2  EL PALACIO DE HIERRO SUCURSAL PUEBLA
# 3  EL PALACIO DE HIERRO SUCURSAL PUEBLA
# 4  EL PALACIO DE HIERRO SUCURSAL PUEBLA
#
#                                            direccion  estado municipio  \
# 0  BLVD DEL NINO POBLANO 2510 PLAZA ANGELOPOLIS C...  PUEBLA    PUEBLA
# 1  BLVD DEL NINO POBLANO 2510 PLAZA ANGELOPOLIS C...  PUEBLA    PUEBLA
# 2  BLVD DEL NINO POBLANO 2510 PLAZA ANGELOPOLIS C...  PUEBLA    PUEBLA
# 3  BLVD DEL NINO POBLANO 2510 PLAZA ANGELOPOLIS C...  PUEBLA    PUEBLA
# 4  BLVD DEL NINO POBLANO 2510 PLAZA ANGELOPOLIS C...  PUEBLA    PUEBLA
#
#      latitud   longitud
# 0  19.030679 -98.234514
# 1  19.030679 -98.234514
# 2  19.030679 -98.234514
# 3  19.030679 -98.234514
# 4  19.030679 -98.234514

# %% [markdown]
# ## Productos de interés
#
# Los productos de interés son,
#
# - Harina de trigo
# - Huevo
# - Azúcar
# - Mantequilla
# - Harina de maíz
# - Leche pasteurizada
# - Leche condensada
# - Canela
# - Manzana

# %%
data = data[data["producto"].isin([
    "HARINA DE TRIGO",
    "HUEVO",
    "AZUCAR",
    "MANTEQUILLA",
    "HARINA DE MAIZ",
    "LECHE PASTEURIZADA",
    "LECHE CONDENSADA",
    "CANELA",
    "MANZANA"
])]
data.shape
# Out:
# (27519, 15)

# %% [markdown]
# ### Harina de trigo

# %%
df = data[data["producto"]=="HARINA DE TRIGO"]
df["presentacion"].unique()
# Out:
# array(['PAQUETE 1 KG', 'PAQUETE 1 KG O 11 KG', 'PAQUETE 1 KG INTEGRAL',
#        'PAQUETE 907 GR', 'PAQUETE 800 O 880 GR', 'PAQUETE 750 GR'],
#       dtype=object)

# %%
dict_harina = {
    "unidades": [
        ("PAQUETE 1 KG", 1000),
        ("PAQUETE 1 KG O 11 KG", 1000),
        ("PAQUETE 1 KG INTEGRAL", 1000),
        ("PAQUETE 907 GR", 907),
        ("PAQUETE 800 O 880 GR", 800),
        ("PAQUETE 750 GR", 750)
    ],
    "tipo":[
        ("PAQUETE 1 KG", "NORMAL"),
        ("PAQUETE 1 KG O 11 KG", "NORMAL"),
        ("PAQUETE 1 KG INTEGRAL", "INTEGRAL"),
        ("PAQUETE 907 GR", "NORMAL"),
        ("PAQUETE 800 O 880 GR", "NORMAL"),
        ("PAQUETE 750 GR", "NORMAL")
    ]
}
dict_harina
# Out:
# {'unidades': [('PAQUETE 1 KG', 1000),
#   ('PAQUETE 1 KG O 11 KG', 1000),
#   ('PAQUETE 1 KG INTEGRAL', 1000),
#   ('PAQUETE 907 GR', 907),
#   ('PAQUETE 800 O 880 GR', 800),
#   ('PAQUETE 750 GR', 750)],
#  'tipo': [('PAQUETE 1 KG', 'NORMAL'),
#   ('PAQUETE 1 KG O 11 KG', 'NORMAL'),
#   ('PAQUETE 1 KG INTEGRAL', 'INTEGRAL'),
#   ('PAQUETE 907 GR', 'NORMAL'),
#   ('PAQUETE 800 O 880 GR', 'NORMAL'),
#   ('PAQUETE 750 GR', 'NORMAL')]}

# %%
unidades_harina = pd.DataFrame(dict_harina.get("unidades"), columns=["presentacion", "unidades"])
tipo_harina = pd.DataFrame(dict_harina.get("tipo"), columns=["presentacion", "tipo"])

info_harina = unidades_harina.merge(tipo_harina, on="presentacion")
info_harina["producto"] = ["HARINA DE TRIGO"] * info_harina.shape[0]
info_harina
# Out:
#             presentacion  unidades      tipo         producto
# 0           PAQUETE 1 KG      1000    NORMAL  HARINA DE TRIGO
# 1   PAQUETE 1 KG O 11 KG      1000    NORMAL  HARINA DE TRIGO
# 2  PAQUETE 1 KG INTEGRAL      1000  INTEGRAL  HARINA DE TRIGO
# 3         PAQUETE 907 GR       907    NORMAL  HARINA DE TRIGO
# 4   PAQUETE 800 O 880 GR       800    NORMAL  HARINA DE TRIGO
# 5         PAQUETE 750 GR       750    NORMAL  HARINA DE TRIGO

# %% [markdown]
# ### Huevo

# %%
df = data[data["producto"]=="HUEVO"]
df["presentacion"].unique()
# Out:
# array(['PAQUETE C12 BLANCO', 'PAQUETE C18 BLANCO',
#        'PAQUETE CON 12 BLANCO', 'PAQUETE CON 18 BLANCO',
#        'PAQUETE C30 BLANCO', 'PAQUETE CON 30 BLANCO'], dtype=object)

# %%
dict_huevo = {
    "unidades": [
        ("PAQUETE C12 BLANCO", 12),
        ("PAQUETE CON 12 BLANCO", 12),
        ("PAQUETE C18 BLANCO", 18),
        ("PAQUETE CON 18 BLANCO", 18),
        ("PAQUETE C30 BLANCO", 30),
        ("PAQUETE CON 30 BLANCO", 30),
    ],
    "tipo":[
        ("PAQUETE C12 BLANCO", "BLANCO"),
        ("PAQUETE CON 12 BLANCO", "BLANCO"),
        ("PAQUETE C18 BLANCO", "BLANCO"),
        ("PAQUETE CON 18 BLANCO", "BLANCO"),
        ("PAQUETE C30 BLANCO", "BLANCO"),
        ("PAQUETE CON 30 BLANCO", "BLANCO"),
    ]
}
dict_huevo
# Out:
# {'unidades': [('PAQUETE C12 BLANCO', 12),
#   ('PAQUETE CON 12 BLANCO', 12),
#   ('PAQUETE C18 BLANCO', 18),
#   ('PAQUETE CON 18 BLANCO', 18),
#   ('PAQUETE C30 BLANCO', 30),
#   ('PAQUETE CON 30 BLANCO', 30)],
#  'tipo': [('PAQUETE C12 BLANCO', 'BLANCO'),
#   ('PAQUETE CON 12 BLANCO', 'BLANCO'),
#   ('PAQUETE C18 BLANCO', 'BLANCO'),
#   ('PAQUETE CON 18 BLANCO', 'BLANCO'),
#   ('PAQUETE C30 BLANCO', 'BLANCO'),
#   ('PAQUETE CON 30 BLANCO', 'BLANCO')]}

# %%
unidades_huevo = pd.DataFrame(dict_huevo.get("unidades"), columns=["presentacion", "unidades"])
tipo_huevo = pd.DataFrame(dict_huevo.get("tipo"), columns=["presentacion", "tipo"])

info_huevo = unidades_huevo.merge(tipo_huevo, on="presentacion")
info_huevo["producto"] = ["HUEVO"] * info_huevo.shape[0]
info_huevo
# Out:
#             presentacion  unidades    tipo producto
# 0     PAQUETE C12 BLANCO        12  BLANCO    HUEVO
# 1  PAQUETE CON 12 BLANCO        12  BLANCO    HUEVO
# 2     PAQUETE C18 BLANCO        18  BLANCO    HUEVO
# 3  PAQUETE CON 18 BLANCO        18  BLANCO    HUEVO
# 4     PAQUETE C30 BLANCO        30  BLANCO    HUEVO
# 5  PAQUETE CON 30 BLANCO        30  BLANCO    HUEVO

# %% [markdown]
# ### Azucar

# %%
df = data[data["producto"]=="AZUCAR"]
df["presentacion"].unique()
# Out:
# array(['CAJA 200 GR 50 SOBRES DE 4 GR CU MASCABADO',
#        'BOLSA PLASTICO 1 KG ESTANDAR',
#        'BOLSA PLASTICO 2 KG ESTANDAR O MORENA',
#        'BOLSA PLASTICO 2 KG REFINADA', 'BOLSA 500 GR MASCABADO',
#        'BOLSA PLASTICO 1 KG ESTANDAR O MORENA',
#        'BOLSA PLASTICO 900 GR ESTANDAR',
#        'BOLSA PLASTICO 1800 GR ESTANDAR O MORENA',
#        'BOLSA PLASTICO 900 GR ESTANDAR O MORENA',
#        'BOLSA PLASTICO 1 KG ESTANDAR MORENA',
#        'BOLSA PLASTICO 2 KG ESTANDAR MORENA',
#        'BOLSA PLASTICO 1 KG REFINADA'], dtype=object)

# %%
dict_azucar = {
    "unidades": [
        ('CAJA 200 GR 50 SOBRES DE 4 GR CU MASCABADO', 200),
        ('BOLSA PLASTICO 1 KG ESTANDAR', 1000),
        ('BOLSA PLASTICO 2 KG ESTANDAR O MORENA', 2000),
        ('BOLSA PLASTICO 2 KG REFINADA', 2000),
        ('BOLSA 500 GR MASCABADO', 500),
        ('BOLSA PLASTICO 1 KG ESTANDAR O MORENA', 1000),
        ('BOLSA PLASTICO 900 GR ESTANDAR', 900),
        ('BOLSA PLASTICO 1800 GR ESTANDAR O MORENA', 1800),
        ('BOLSA PLASTICO 900 GR ESTANDAR O MORENA', 900),
        ('BOLSA PLASTICO 1 KG ESTANDAR MORENA', 1000),
        ('BOLSA PLASTICO 2 KG ESTANDAR MORENA', 2000),
        ('BOLSA PLASTICO 1 KG REFINADA', 1000)
    ],
    "tipo":[
        ('CAJA 200 GR 50 SOBRES DE 4 GR CU MASCABADO', "MASCABADO"),
        ('BOLSA PLASTICO 1 KG ESTANDAR', "ESTANDAR"),
        ('BOLSA PLASTICO 2 KG ESTANDAR O MORENA', "ESTANDAR"),
        ('BOLSA PLASTICO 2 KG ESTANDAR O MORENA', "MORENA"),
        ('BOLSA PLASTICO 2 KG REFINADA', "REFINADA"),
        ('BOLSA 500 GR MASCABADO', "MASCABADO"),
        ('BOLSA PLASTICO 1 KG ESTANDAR O MORENA', "ESTANDAR"),
        ('BOLSA PLASTICO 1 KG ESTANDAR O MORENA', "MORENA"),
        ('BOLSA PLASTICO 900 GR ESTANDAR', "ESTANDAR"),
        ('BOLSA PLASTICO 1800 GR ESTANDAR O MORENA', "ESTANDAR"),
        ('BOLSA PLASTICO 1800 GR ESTANDAR O MORENA', "MORENA"),
        ('BOLSA PLASTICO 900 GR ESTANDAR O MORENA', "ESTANDAR"),
        ('BOLSA PLASTICO 900 GR ESTANDAR O MORENA', "MORENA"),
        ('BOLSA PLASTICO 1 KG ESTANDAR MORENA', "ESTANDAR"),
        ('BOLSA PLASTICO 1 KG ESTANDAR MORENA', "MORENA"),
        ('BOLSA PLASTICO 2 KG ESTANDAR MORENA', "ESTANDAR"),
        ('BOLSA PLASTICO 2 KG ESTANDAR MORENA', "MORENA"),
        ('BOLSA PLASTICO 1 KG REFINADA', "REFINADA")
    ]
}
dict_azucar
# Out:
# {'unidades': [('CAJA 200 GR 50 SOBRES DE 4 GR CU MASCABADO', 200),
#   ('BOLSA PLASTICO 1 KG ESTANDAR', 1000),
#   ('BOLSA PLASTICO 2 KG ESTANDAR O MORENA', 2000),
#   ('BOLSA PLASTICO 2 KG REFINADA', 2000),
#   ('BOLSA 500 GR MASCABADO', 500),
#   ('BOLSA PLASTICO 1 KG ESTANDAR O MORENA', 1000),
#   ('BOLSA PLASTICO 900 GR ESTANDAR', 900),
#   ('BOLSA PLASTICO 1800 GR ESTANDAR O MORENA', 1800),
#   ('BOLSA PLASTICO 900 GR ESTANDAR O MORENA', 900),
#   ('BOLSA PLASTICO 1 KG ESTANDAR MORENA', 1000),
#   ('BOLSA PLASTICO 2 KG ESTANDAR MORENA', 2000),
#   ('BOLSA PLASTICO 1 KG REFINADA', 1000)],
#  'tipo': [('CAJA 200 GR 50 SOBRES DE 4 GR CU MASCABADO', 'MASCABADO'),
#   ('BOLSA PLASTICO 1 KG ESTANDAR', 'ESTANDAR'),
#   ('BOLSA PLASTICO 2 KG ESTANDAR O MORENA', 'ESTANDAR'),
#   ('BOLSA PLASTICO 2 KG ESTANDAR O MORENA', 'MORENA'),
#   ('BOLSA PLASTICO 2 KG REFINADA', 'REFINADA'),
#   ('BOLSA 500 GR MASCABADO', 'MASCABADO'),
#   ('BOLSA PLASTICO 1 KG ESTANDAR O MORENA', 'ESTANDAR'),
#   ('BOLSA PLASTICO 1 KG ESTANDAR O MORENA', 'MORENA'),
#   ('BOLSA PLASTICO 900 GR ESTANDAR', 'ESTANDAR'),
#   ('BOLSA PLASTICO 1800 GR ESTANDAR O MORENA', 'ESTANDAR'),
#   ('BOLSA PLASTICO 1800 GR ESTANDAR O MORENA', 'MORENA'),
#   ('BOLSA PLASTICO 900 GR ESTANDAR O MORENA', 'ESTANDAR'),
#   ('BOLSA PLASTICO 900 GR ESTANDAR O MORENA', 'MORENA'),
#   ('BOLSA PLASTICO 1 KG ESTANDAR MORENA', 'ESTANDAR'),
#   ('BOLSA PLASTICO 1 KG ESTANDAR MORENA', 'MORENA'),
#   ('BOLSA PLASTICO 2 KG ESTANDAR MORENA', 'ESTANDAR'),
#   ('BOLSA PLASTICO 2 KG ESTANDAR MORENA', 'MORENA'),
#   ('BOLSA PLASTICO 1 KG REFINADA', 'REFINADA')]}

# %%
unidades_azucar = pd.DataFrame(dict_azucar.get("unidades"), columns=["presentacion", "unidades"])
tipo_azucar = pd.DataFrame(dict_azucar.get("tipo"), columns=["presentacion", "tipo"])

info_azucar = unidades_azucar.merge(tipo_azucar, on="presentacion")
info_azucar["producto"] = ["AZUCAR"] * info_azucar.shape[0]
info_azucar
# Out:
#                                   presentacion  unidades       tipo producto
# 0   CAJA 200 GR 50 SOBRES DE 4 GR CU MASCABADO       200  MASCABADO   AZUCAR
# 1                 BOLSA PLASTICO 1 KG ESTANDAR      1000   ESTANDAR   AZUCAR
# 2        BOLSA PLASTICO 2 KG ESTANDAR O MORENA      2000   ESTANDAR   AZUCAR
# 3        BOLSA PLASTICO 2 KG ESTANDAR O MORENA      2000     MORENA   AZUCAR
# 4                 BOLSA PLASTICO 2 KG REFINADA      2000   REFINADA   AZUCAR
# 5                       BOLSA 500 GR MASCABADO       500  MASCABADO   AZUCAR
# 6        BOLSA PLASTICO 1 KG ESTANDAR O MORENA      1000   ESTANDAR   AZUCAR
# 7        BOLSA PLASTICO 1 KG ESTANDAR O MORENA      1000     MORENA   AZUCAR
# 8               BOLSA PLASTICO 900 GR ESTANDAR       900   ESTANDAR   AZUCAR
# 9     BOLSA PLASTICO 1800 GR ESTANDAR O MORENA      1800   ESTANDAR   AZUCAR
# 10    BOLSA PLASTICO 1800 GR ESTANDAR O MORENA      1800     MORENA   AZUCAR
# 11     BOLSA PLASTICO 900 GR ESTANDAR O MORENA       900   ESTANDAR   AZUCAR
# 12     BOLSA PLASTICO 900 GR ESTANDAR O MORENA       900     MORENA   AZUCAR
# 13         BOLSA PLASTICO 1 KG ESTANDAR MORENA      1000   ESTANDAR   AZUCAR
# 14         BOLSA PLASTICO 1 KG ESTANDAR MORENA      1000     MORENA   AZUCAR
# 15         BOLSA PLASTICO 2 KG ESTANDAR MORENA      2000   ESTANDAR   AZUCAR
# 16         BOLSA PLASTICO 2 KG ESTANDAR MORENA      2000     MORENA   AZUCAR
# 17                BOLSA PLASTICO 1 KG REFINADA      1000   REFINADA   AZUCAR

# %%
info_productos = pd.concat([info_harina, info_huevo, info_azucar]).reset_index(drop=True)
info_productos
# Out:
#                                   presentacion  unidades       tipo  \
# 0                                 PAQUETE 1 KG      1000     NORMAL
# 1                         PAQUETE 1 KG O 11 KG      1000     NORMAL
# 2                        PAQUETE 1 KG INTEGRAL      1000   INTEGRAL
# 3                               PAQUETE 907 GR       907     NORMAL
# 4                         PAQUETE 800 O 880 GR       800     NORMAL
# 5                               PAQUETE 750 GR       750     NORMAL
# 6                           PAQUETE C12 BLANCO        12     BLANCO
# 7                        PAQUETE CON 12 BLANCO        12     BLANCO
# 8                           PAQUETE C18 BLANCO        18     BLANCO
# 9                        PAQUETE CON 18 BLANCO        18     BLANCO
# 10                          PAQUETE C30 BLANCO        30     BLANCO
# 11                       PAQUETE CON 30 BLANCO        30     BLANCO
# 12  CAJA 200 GR 50 SOBRES DE 4 GR CU MASCABADO       200  MASCABADO
# 13                BOLSA PLASTICO 1 KG ESTANDAR      1000   ESTANDAR
# 14       BOLSA PLASTICO 2 KG ESTANDAR O MORENA      2000   ESTANDAR
# 15       BOLSA PLASTICO 2 KG ESTANDAR O MORENA      2000     MORENA
# 16                BOLSA PLASTICO 2 KG REFINADA      2000   REFINADA
# 17                      BOLSA 500 GR MASCABADO       500  MASCABADO
# 18       BOLSA PLASTICO 1 KG ESTANDAR O MORENA      1000   ESTANDAR
# 19       BOLSA PLASTICO 1 KG ESTANDAR O MORENA      1000     MORENA
# 20              BOLSA PLASTICO 900 GR ESTANDAR       900   ESTANDAR
# 21    BOLSA PLASTICO 1800 GR ESTANDAR O MORENA      1800   ESTANDAR
# 22    BOLSA PLASTICO 1800 GR ESTANDAR O MORENA      1800     MORENA
# 23     BOLSA PLASTICO 900 GR ESTANDAR O MORENA       900   ESTANDAR
# 24     BOLSA PLASTICO 900 GR ESTANDAR O MORENA       900     MORENA
# 25         BOLSA PLASTICO 1 KG ESTANDAR MORENA      1000   ESTANDAR
# 26         BOLSA PLASTICO 1 KG ESTANDAR MORENA      1000     MORENA
# 27         BOLSA PLASTICO 2 KG ESTANDAR MORENA      2000   ESTANDAR
# 28         BOLSA PLASTICO 2 KG ESTANDAR MORENA      2000     MORENA
# 29                BOLSA PLASTICO 1 KG REFINADA      1000   REFINADA
#
#            producto
# 0   HARINA DE TRIGO
# 1   HARINA DE TRIGO
# 2   HARINA DE TRIGO
# 3   HARINA DE TRIGO
# 4   HARINA DE TRIGO
# 5   HARINA DE TRIGO
# 6             HUEVO
# 7             HUEVO
# 8             HUEVO
# 9             HUEVO
# 10            HUEVO
# 11            HUEVO
# 12           AZUCAR
# 13           AZUCAR
# 14           AZUCAR
# 15           AZUCAR
# 16           AZUCAR
# 17           AZUCAR
# 18           AZUCAR
# 19           AZUCAR
# 20           AZUCAR
# 21           AZUCAR
# 22           AZUCAR
# 23           AZUCAR
# 24           AZUCAR
# 25           AZUCAR
# 26           AZUCAR
# 27           AZUCAR
# 28           AZUCAR
# 29           AZUCAR

# %%
data_productos = data.merge(info_productos, how="inner", on=["producto", "presentacion"])
data_productos
# Out:
#       producto                                presentacion        marca  \
# 0       AZUCAR  CAJA 200 GR 50 SOBRES DE 4 GR CU MASCABADO       DOMINO
# 1       AZUCAR                BOLSA PLASTICO 1 KG ESTANDAR  GREAT VALUE
# 2       AZUCAR       BOLSA PLASTICO 2 KG ESTANDAR O MORENA  GREAT VALUE
# 3       AZUCAR       BOLSA PLASTICO 2 KG ESTANDAR O MORENA  GREAT VALUE
# 4       AZUCAR                BOLSA PLASTICO 2 KG REFINADA  GREAT VALUE
# ...        ...                                         ...          ...
# 16866    HUEVO                          PAQUETE C18 BLANCO   PRECISSIMO
# 16867    HUEVO                       PAQUETE CON 12 BLANCO     SAN JUAN
# 16868    HUEVO                       PAQUETE CON 18 BLANCO     SAN JUAN
# 16869    HUEVO                       PAQUETE CON 30 BLANCO     SAN JUAN
# 16870    HUEVO                          PAQUETE C30 BLANCO     TEHUACAN
#
#       categoria catalogo  precio  fechaRegistro       cadenaComercial  \
# 0        AZUCAR  BASICOS    17.5       20230102               WALMART
# 1        AZUCAR    PACIC    24.0       20230102               WALMART
# 2        AZUCAR  BASICOS    55.0       20230102               WALMART
# 3        AZUCAR  BASICOS    55.0       20230102               WALMART
# 4        AZUCAR  BASICOS    62.0       20230102               WALMART
# ...         ...      ...     ...            ...                   ...
# 16866     HUEVO    PACIC    49.0       20221230  HIPERMERCADO SORIANA
# 16867     HUEVO  BASICOS    35.5       20221230  HIPERMERCADO SORIANA
# 16868     HUEVO  BASICOS    49.0       20221230  HIPERMERCADO SORIANA
# 16869     HUEVO  BASICOS    84.9       20221230  HIPERMERCADO SORIANA
# 16870     HUEVO  BASICOS    83.0       20221230  HIPERMERCADO SORIANA
#
#                                        giro  \
# 0      SUPERMERCADO  TIENDA DE AUTOSERVICIO
# 1      SUPERMERCADO  TIENDA DE AUTOSERVICIO
# 2      SUPERMERCADO  TIENDA DE AUTOSERVICIO
# 3      SUPERMERCADO  TIENDA DE AUTOSERVICIO
# 4      SUPERMERCADO  TIENDA DE AUTOSERVICIO
# ...                                     ...
# 16866  SUPERMERCADO  TIENDA DE AUTOSERVICIO
# 16867  SUPERMERCADO  TIENDA DE AUTOSERVICIO
# 16868  SUPERMERCADO  TIENDA DE AUTOSERVICIO
# 16869  SUPERMERCADO  TIENDA DE AUTOSERVICIO
# 16870  SUPERMERCADO  TIENDA DE AUTOSERVICIO
#
#                              nombreComercial  \
# 0                  WALMART SUCURSAL  REFORMA
# 1                  WALMART SUCURSAL  REFORMA
# 2                  WALMART SUCURSAL  REFORMA
# 3                  WALMART SUCURSAL  REFORMA
# 4                  WALMART SUCURSAL  REFORMA
# ...                                      ...
# 16866  SORIANA HIPER SUCURSAL TORRECILLAS 96
# 16867  SORIANA HIPER SUCURSAL TORRECILLAS 96
# 16868  SORIANA HIPER SUCURSAL TORRECILLAS 96
# 16869  SORIANA HIPER SUCURSAL TORRECILLAS 96
# 16870  SORIANA HIPER SUCURSAL TORRECILLAS 96
#
#                                                direccion  estado municipio  \
# 0      AV DE LA REFORMA SUR 3117 CHAPULCO Y ARON MERI...  PUEBLA    PUEBLA
# 1      AV DE LA REFORMA SUR 3117 CHAPULCO Y ARON MERI...  PUEBLA    PUEBLA
# 2      AV DE LA REFORMA SUR 3117 CHAPULCO Y ARON MERI...  PUEBLA    PUEBLA
# 3      AV DE LA REFORMA SUR 3117 CHAPULCO Y ARON MERI...  PUEBLA    PUEBLA
# 4      AV DE LA REFORMA SUR 3117 CHAPULCO Y ARON MERI...  PUEBLA    PUEBLA
# ...                                                  ...     ...       ...
# 16866  MUNICIPIO LIBRE 555 ENTRE NAYARIT Y 5 DE MAYO ...  PUEBLA    PUEBLA
# 16867  MUNICIPIO LIBRE 555 ENTRE NAYARIT Y 5 DE MAYO ...  PUEBLA    PUEBLA
# 16868  MUNICIPIO LIBRE 555 ENTRE NAYARIT Y 5 DE MAYO ...  PUEBLA    PUEBLA
# 16869  MUNICIPIO LIBRE 555 ENTRE NAYARIT Y 5 DE MAYO ...  PUEBLA    PUEBLA
# 16870  MUNICIPIO LIBRE 555 ENTRE NAYARIT Y 5 DE MAYO ...  PUEBLA    PUEBLA
#
#          latitud   longitud  unidades       tipo
# 0      19.058213 -98.223349       200  MASCABADO
# 1      19.058213 -98.223349      1000   ESTANDAR
# 2      19.058213 -98.223349      2000   ESTANDAR
# 3      19.058213 -98.223349      2000     MORENA
# 4      19.058213 -98.223349      2000   REFINADA
# ...          ...        ...       ...        ...
# 16866  19.001040 -98.229813        18     BLANCO
# 16867  19.001040 -98.229813        12     BLANCO
# 16868  19.001040 -98.229813        18     BLANCO
# 16869  19.001040 -98.229813        30     BLANCO
# 16870  19.001040 -98.229813        30     BLANCO
#
# [16871 rows x 17 columns]

# %%
data_productos["fechaRegistro"] = [f"{num//10000}/{(num % 10000)//100}/{num % 100}" for num in data_productos["fechaRegistro"]]

# %%
data_productos.to_csv("data\\datos_productos_seleccionados.csv")
